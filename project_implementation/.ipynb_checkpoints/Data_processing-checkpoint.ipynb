# %%
# import dep. 


import pandas as pd 
import numpy as np

# %%
data_commedia = pd.read_csv("../data_collection/data/LAB-STICC_COMMEDIA_data.csv", skiprows=1)
# data_rambo = pd.load_csv("../data_collection/data/LAB-STICC_RAMBO_data.csv")
# data_inuit = pd.load_csv("../data_collection/data/LAB-STICC_INUIT_data.csv")

# %%
data_commedia.head(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                      ['Improving Neural Architecture Search by Mixing a FireFly algorithm with a Training Free Evaluation']  \
# ['Indifferent or Enthusiastic? Virtual Audience... ['In this paper                                     we present a virtual audience simulation syste...  such as facial expressions or postures. Groups...  indifferent or enthusiastic). Each rule specif...  head movement                                      facial expression and gaze direction as well a...   frequency and proportion . In a first user-study
# ...

# %%
data_commedia.shape
# Out:
# (31, 12)
